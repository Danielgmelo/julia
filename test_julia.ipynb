# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
x = 1:10; y = rand(10); # These are the plotting data 
plot(x,y, label="my label")

# %%
using CSV
# Out:
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1260

# %%
d = CSV.read("data_selling_per_month.csv")
# Out:
# 12×3 DataFrames.DataFrame
# │ Row │ month │ volume │ volume2 │
# │     │ Int64 │ Int64  │ Int64   │
# ├─────┼───────┼────────┼─────────┤
# │ 1   │ 1     │ 100    │ 85      │
# │ 2   │ 2     │ 350    │ 335     │
# │ 3   │ 3     │ 592    │ 577     │
# │ 4   │ 4     │ 400    │ 385     │
# │ 5   │ 5     │ 200    │ 185     │
# │ 6   │ 6     │ 216    │ 201     │
# │ 7   │ 7     │ 432    │ 417     │
# │ 8   │ 8     │ 288    │ 273     │
# │ 9   │ 9     │ 340    │ 325     │
# │ 10  │ 10    │ 240    │ 225     │
# │ 11  │ 11    │ 456    │ 441     │
# │ 12  │ 12    │ 760    │ 745     │

# %%
bar(d.month, d.volume)

# %%
plot(d.month, [d.volume, d.volume2])

# %%
scatter(d.volume,d.volume2)

# %%
x = 1:5; y = rand(5); # These are the plotting data
pie(x,y)
savefig("exemplo.png")

# %%
print(d)
# Out:
# 12×3 DataFrames.DataFrame
# │ Row │ month │ volume │ volume2 │
# │     │ Int64 │ Int64  │ Int64   │
# ├─────┼───────┼────────┼─────────┤
# │ 1   │ 1     │ 100    │ 85      │
# │ 2   │ 2     │ 350    │ 335     │
# │ 3   │ 3     │ 592    │ 577     │
# │ 4   │ 4     │ 400    │ 385     │
# │ 5   │ 5     │ 200    │ 185     │
# │ 6   │ 6     │ 216    │ 201     │
# │ 7   │ 7     │ 432    │ 417     │
# │ 8   │ 8     │ 288    │ 273     │
# │ 9   │ 9     │ 340    │ 325     │
# │ 10  │ 10    │ 240    │ 225     │
# │ 11  │ 11    │ 456    │ 441     │
# │ 12  │ 12    │ 760    │ 745     │
